# %%
from sklearn import neighbors, datasets
import pylab as pl
import numpy as np
iris = datasets.load_iris()



h = .02



X = iris.data[:, :5] 
Y = iris.target

mean_data = Y.groupby("Species").mean()

pl.scatter(X[:,0], X[:,1],c=Y )
pl.xlabel('Sepal length')
pl.ylabel('Sepal width')

pl.xlim(xx.min(), xx.max())
pl.ylim(yy.min(), yy.max())
pl.xticks(())
pl.yticks(())

pl.savefig("chart.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/egemengulpinar/Desktop/MEU_LAST_YEAR/XML/trial_final_projects/flask-machine-learning-model-CRUD/results.ipynb Cell 1' in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/egemengulpinar/Desktop/MEU_LAST_YEAR/XML/trial_final_projects/flask-machine-learning-model-CRUD/results.ipynb#ch0000000?line=11'>12</a> X = iris.data[:, :5]
#      <a href='vscode-notebook-cell:/Users/egemengulpinar/Desktop/MEU_LAST_YEAR/XML/trial_final_projects/flask-machine-learning-model-CRUD/results.ipynb#ch0000000?line=12'>13</a> Y = iris.target
# ---> <a href='vscode-notebook-cell:/Users/egemengulpinar/Desktop/MEU_LAST_YEAR/XML/trial_final_projects/flask-machine-learning-model-CRUD/results.ipynb#ch0000000?line=14'>15</a> mean_data = Y.groupby("Species").mean()
#      <a href='vscode-notebook-cell:/Users/egemengulpinar/Desktop/MEU_LAST_YEAR/XML/trial_final_projects/flask-machine-learning-model-CRUD/results.ipynb#ch0000000?line=16'>17</a> pl.scatter(X[:,0], X[:,1],c=Y )
#      <a href='vscode-notebook-cell:/Users/egemengulpinar/Desktop/MEU_LAST_YEAR/XML/trial_final_projects/flask-machine-learning-model-CRUD/results.ipynb#ch0000000?line=17'>18</a> pl.xlabel('Sepal length')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'groupby'

# %%
X = iris.data[:, :4] 
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
np.std(iris.data[:, :4] )
# Out:
# 1.9738430577598278

# %%
import pandas as pd
data = pd.read_csv("Iris.csv")

temp_data = pd.DataFrame(data)
mean_data = temp_data.groupby("Species").mean()
print(mean_data)
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
#In this section, I drew all avg species plot results
np.random.seed(19680801)
import matplotlib.pyplot as plt
#! pip install plotly==5.8.0
import plotly.express as px
import seaborn as sns
import pandas as pd
data = pd.read_csv("Iris.csv")

temp_data = pd.DataFrame(data)
mean_data = temp_data.groupby("Species").mean()

barWidth = 0.13
fig = plt.subplots(figsize =(5, 8))

 
# Set position of bar on X axis
br1 = np.arange(3)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
 
# Make the plot
plt.bar(br1, mean_data["SepalLengthCm"], color ='r', width = barWidth,
        edgecolor ='grey', label ='SepalLengthCm')
plt.bar(br2, mean_data["SepalWidthCm"], color ='g', width = barWidth,
        edgecolor ='grey', label ='SepalWidthCm')
plt.bar(br3, mean_data["PetalLengthCm"], color ='b', width = barWidth,
        edgecolor ='grey', label ='PetalLengthCm')
plt.bar(br4, mean_data["PetalWidthCm"], color ='y', width = barWidth,
        edgecolor ='grey', label ='PetalWidthCm')
 
# Adding Xticks
plt.xlabel('Species', fontweight ='bold', fontsize = 15)
plt.ylabel('Avg Values', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(3)],
        ['Iris-setosa', 'Iris-versicolor ', 'Iris-virginica'])
 
plt.legend()
plt.savefig("chart.png")

# %%
g = sns.pairplot(data, hue='Species', markers='o',palette='prism')
